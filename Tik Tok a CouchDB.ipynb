# %%
import json
from bson import json_util, ObjectId
import couchdb

# %%
#el archivo json debe estar en la misma carpeta que el proyecto
with open ("videojuegos.json", encoding="utf8") as j:
    myJson = json.load(j)

# %%
server=couchdb.Server('http://admin:admin@127.0.0.1:5984')
try:
    db = server.create('tiktok')
    print("Base de Datos creada en CouchDB")
except:
    db =server['tiktok']

# %%
#Para couchDB
#la variable x reocrre todo la documentacion de la variable myjson 
for x in myJson:
    try:
        documents=json.loads(json_util.dumps(x))
        print(documents)
        db.save(documents)
    except TypeError as t:
        print('current document raised error: {}'.format(t))
        SKIPPED.append(x)  
        continue
# Out:
# {'id': '6947711087416495366', 'secretID': '6947711087416495366', 'text': 'Todo ese dinero solo por jugar 2 horas 😭 #gaming #videojuegos #clashroyale #twitch #fyp', 'createTime': 1617640047, 'authorMeta': {'id': '6848775798061892614', 'secUid': 'MS4wLjABAAAAlHqfIQPn9NAVWljGaOZL2hcy1ZFVNXuW3zhKXKic7J-BWrKP4pFT22YOq75zqlYG', 'name': 'darklightcr', 'nickName': 'Iker Villarreal', 'verified': True, 'signature': 'Jugador profesional de Clash Royale\nChivas esports', 'avatar': 'https://p16-sign-va.tiktokcdn.com/tos-maliva-avt-0068/28c2b28e7c286a8e827d6b80fb8c7dc8~c5_1080x1080.jpeg?x-expires=1644786000&x-signature=W4yJCWp0%2BmQrBeGVMJUO5%2FkywpY%3D', 'following': 32, 'fans': 2100000, 'heart': 54600000, 'video': 278, 'digg': 17700}, 'musicMeta': {'musicId': '6847581036629460993', 'musicName': 'Send Me on My Way', 'musicAuthor': 'Vibe Street', 'musicOriginal': False, 'musicAlbum': "Vibin' on Em (The Remix)- EP", 'playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/tos-useast2a-ve-2774/58ca5d
# ...
