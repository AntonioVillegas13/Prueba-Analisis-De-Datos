# %%
import json
from argparse import ArgumentParser
import requests
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
from bson import json_util, ObjectId
import couchdb
import mysql.connector as msql
import pandas as pd
from sqlalchemy import create_engine
import certifi
import numpy as np

# %%
try:
    ca = certifi.where()
    client = MongoClient('mongodb+srv://1223:1223@cluster0.zzwgm.mongodb.net/myFirstDatabase?retryWrites=true&w=majority', tlsCAFile=ca )

    client.server_info()
    print("Conexion exitosa")
    client.close
except pymongo.errors.ServerSelectionTimeoutError as errorTiempo:
    print("Conexión rechazada1")
dbm = client['Recibimiento']
cole = dbm['datos_desde_SQL']
# Out:
# Conexion exitosa

# %%
host = 'localhost'
port = 3306
db = 'ITERCAMBIO'
user = 'root'
password = 'casa'

# %%
engine = create_engine('mysql+mysqldb://root:casa@localhost:3306/ITERCAMBIO')

# %%
connections = msql.connect(host = 'localhost', user = 'root')
if connections.is_connected():
    cursor = connections.cursor()
    print("Conexión con la base de datos realizada")
else:
    print("Conexion Rechazada")
# Out:
# Conexión con la base de datos realizada

# %%
connections = msql.connect(host = 'localhost', user = 'root', database ='ITERCAMBIO')
if connections.is_connected():
    cursor = connections.cursor()
    cursor.execute("select database();")
    record = cursor.fetchone()
    print("Se conectó a la base de datos: ", record)
# Out:
# Se conectó a la base de datos:  ('itercambio',)

# %%
tomongo= pd.read_sql("SELECT * FROM facebook2", connections)
tomongo
# Out:
#     Unnamed: 0                       _id                   id  \
# 0            0  620863d6ae8fb09cebd27a08  1492614077465739268
# 1            1  620863d7ae8fb09cebd27a09  1492614104309121024
# 2            2  620863d7ae8fb09cebd27a0a  1492614105148047362
# 3            3  620863d7ae8fb09cebd27a0b  1492614107861852166
# 4            4  620863d7ae8fb09cebd27a0c  1492614116665659400
# 5            5  620863d8ae8fb09cebd27a0d  1492614118649606145
# 6            6  620863e4ae8fb09cebd27a0f  1492614077465739268
# 7            7  620863e5ae8fb09cebd27a10  1492614104309121024
# 8            8  620863e5ae8fb09cebd27a11  1492614105148047362
# 9            9  620863e5ae8fb09cebd27a12  1492614107861852166
# 10          10  620863e6ae8fb09cebd27a13  1492614116665659400
# 11          11  620863e6ae8fb09cebd27a14  1492614118649606145
# 12          12  620863f0ae8fb09cebd27a16  1492614077465739268
# 13          13  620863f1ae8fb09cebd27a17  1492614104309121024
# ...

# %%
def createDocsFromDF(tomongo, collection = None, insertToDB=False):
    docs = []
    fields = [col for col in tomongo.columns]
    for i in range(len(tomongo)):
        doc = {col:tomongo[col][i] for col in tomongo.columns if col != 'index'}
        for key, val in doc.items():
            if type(val) == np.int64:
                doc[key] = int(val)
            if type(val) == np.float64:
                doc[key] = float(val)
            if type(val) == np.bool_:
                doc[key] = bool(val)
        docs.append(doc) 
    if isinstance(docs, list): 
        cole.insert_many(docs)   
    else: 
        cole.insert_one(docs)
    print("guardado exitosamente")    
    return docs

# %%
createDocsFromDF(tomongo)
# Out:
# guardado exitosamente
# [{'Unnamed: 0': 0,
#   '_id': '620863d6ae8fb09cebd27a08',
#   'id': 1492614077465739268,
#   'texto': 'Good day out at Bristol Independent Gamers for Winter Wonder Lard. Thanks to @andre_crow and @SvelhlauprDavid  for… https://t.co/jMENuINUA3',
#   'coordinates': None},
#  {'Unnamed: 0': 1,
#   '_id': '620863d7ae8fb09cebd27a09',
#   'id': 1492614104309121024,
#   'texto': '@Ozard_OfWiz @Sparticuszorro 18yo gamers at home are themselves second in line to 22yo ML engineers at home. \n\nshop… https://t.co/YUNvOI058d',
#   'coordinates': None},
#  {'Unnamed: 0': 2,
#   '_id': '620863d7ae8fb09cebd27a0a',
#   'id': 1492614105148047362,
#   'texto': '@Dr_Died @rttanks @HffRts @Rts_WW @BlazedRTs @sme_rt @PromoteAMGamers @rtsmallstreams @SupStreamers @promo_streams… https://t.co/jxdALa7i0x',
#   'coordinates': None},
#  {'Unnamed: 0': 3,
#   '_id': '620863d7ae8fb09cebd27a0b',
#   'id': 1492614107861852166,
# ...
